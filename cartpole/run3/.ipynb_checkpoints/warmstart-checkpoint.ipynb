# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.read_csv("fooBar.csv")
data = df.values

# %%
data.shape
# Out:
# (9999, 305)

# %%
print("Shape x_train -> 0 : 4, value function = index 4, then (x, y, z, theta, control, cost)..repeated")
print("T -> 50, so T x 6 = 300, + 5 ")
# Out:
# Shape x_train -> 0 : 4, value function = index 4, then (x, y, z, theta, control, cost)..repeated
# T -> 50, so T x 6 = 300, + 5

# %%
from baselineNet import *
# Out:
# Using TensorFlow backend.

# %%
x_data = data[:,0:4]
y_data = data[:,4:]

# %%
print(x_data.shape)
print(y_data.shape)
# Out:
# (9999, 4)
# (9999, 301)

# %%
net = kerasNet(x_data,
             y_data,
             NUNITS_INPUT = 64,
             NUNITS = 128,
             NHIDDEN = 2,
             lr = 1e-3,
             EPOCHS = 100,
             BATCHSIZE = 64,
             validation_split = 0.1,
             VERBOSE = 2,
             optimizer = "adam",
             loss = ['mean_squared_error'],
             use_gpu = True,
             saveModel = False,
             plot_results = True,
             baseline = False    )
# Out:
# Using gpu!
# X_Train :  (9999, 4)  and Y_Train:  (9999, 301)
# Train on 8999 samples, validate on 1000 samples
# Epoch 1/100
#  - 1s - loss: 9.3799 - mse: 7.9992 - rmse: 2.4913 - max_error: 75.7093 - mae: 1.4721 - val_loss: 8.2230 - val_mse: 7.8788 - val_rmse: 2.4660 - val_max_error: 76.7304 - val_mae: 1.4519
# Epoch 2/100
#  - 0s - loss: 8.1655 - mse: 7.9336 - rmse: 2.4781 - max_error: 74.5536 - mae: 1.4558 - val_loss: 7.9964 - val_mse: 7.8172 - val_rmse: 2.4533 - val_max_error: 76.5924 - val_mae: 1.4379
# Epoch 3/100
#  - 0s - loss: 8.0141 - mse: 7.8778 - rmse: 2.4671 - max_error: 74.5448 - mae: 1.4434 - val_loss: 7.8987 - val_mse: 7.7699 - val_rmse: 2.4438 - val_max_error: 76.4551 - val_mae: 1.4282
# Epoch 4/100
#  - 0s - loss: 7.9474 - mse: 7.8326 - rmse: 2.4585 - max_error: 74.6509 - mae: 1.4343 - val_loss: 7.8438 - val_mse: 7.7301 - val_rmse: 2.4359 - val_max_error: 76.3190 - val_mae: 1.4206
# Epoch 5/100
#  - 0s - loss: 7.9021 - mse: 7.7956 - rmse: 2.4516 - max_error: 73.5659 - mae: 1.4278 - val_loss: 7.8094 - val_mse: 7.6975 - val_rmse: 2.4296 - val_max_error: 76.1831 - val_mae: 1.4153
# Epoch 6/100
#  - 0s - loss: 7.8643 - mse: 7.7649 - rmse: 2.4459 - max_error: 73.2219 - mae: 1.4228 - val_loss: 7.7747 - val_mse: 7.6700 - val_rmse: 2.4244 - val_max_error: 76.0474 - val_mae: 1.4114
# Epoch 7/100
#  - 0s - loss: 7.8321 - mse: 7.7391 - rmse: 2.4412 - max_error: 73.3991 - mae: 1.4191 - val_loss: 7.7435 - val_mse: 7.6472 - val_rmse: 2.4202 - val_max_error: 75.9132 - val_mae: 1.4084
# Epoch 8/100
#  - 0s - loss: 7.8038 - mse: 7.7172 - rmse: 2.4373 - max_error: 73.3773 - mae: 1.4163 - val_loss: 7.7094 - val_mse: 7.6271 - val_rmse: 2.4166 - val_max_error: 75.7793 - val_mae: 1.4060
#  - 0s - loss: 7.3208 - mse: 7.2995 - rmse: 2.4096 - max_error: 65.1559 - mae: 1.4075 - val_loss: 7.2539 - val_mse: 7.2280 - val_rmse: 2.3921 - val_max_error: 66.3158 - val_mae: 1.3988
# Epoch 95/100
#  - 0s - loss: 7.3172 - mse: 7.2990 - rmse: 2.4099 - max_error: 64.7616 - mae: 1.4075 - val_loss: 7.2502 - val_mse: 7.2276 - val_rmse: 2.3925 - val_max_error: 66.2552 - val_mae: 1.3988
# Epoch 96/100
#  - 0s - loss: 7.3155 - mse: 7.2985 - rmse: 2.4102 - max_error: 62.6697 - mae: 1.4074 - val_loss: 7.2460 - val_mse: 7.2271 - val_rmse: 2.3928 - val_max_error: 66.1924 - val_mae: 1.3988
# Epoch 97/100
#  - 0s - loss: 7.3152 - mse: 7.2981 - rmse: 2.4106 - max_error: 64.4043 - mae: 1.4075 - val_loss: 7.2480 - val_mse: 7.2267 - val_rmse: 2.3931 - val_max_error: 66.1374 - val_mae: 1.3989
# Epoch 98/100
#  - 0s - loss: 7.3148 - mse: 7.2977 - rmse: 2.4109 - max_error: 63.5544 - mae: 1.4075 - val_loss: 7.2440 - val_mse: 7.2263 - val_rmse: 2.3934 - val_max_error: 66.0838 - val_mae: 1.3989
# Epoch 99/100
#  - 0s - loss: 7.3151 - mse: 7.2973 - rmse: 2.4112 - max_error: 63.9559 - mae: 1.4076 - val_loss: 7.2484 - val_mse: 7.2261 - val_rmse: 2.3938 - val_max_error: 66.0276 - val_mae: 1.3989
# Epoch 100/100
#  - 0s - loss: 7.3145 - mse: 7.2970 - rmse: 2.4115 - max_error: 64.4954 - mae: 1.4077 - val_loss: 7.2494 - val_mse: 7.2258 - val_rmse: 2.3941 - val_max_error: 65.9760 - val_mae: 1.3990
# Model: "Network1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# First (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# Final (Dense)                (None, 301)               38829
# =================================================================
# Total params: 63,981
# Trainable params: 63,981
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from timeit import default_timer as timer
import crocoddyl
from data import *
from plotTable import *
crocoddyl.switchToNumpyArray()

# %%
iterations = []
time = []
for _ in range(100):
    

    x0 = [random.uniform(0,1), random.uniform(-3.14, 3.14), random.uniform(0., 1), 0.]
    x_test = np.array(x0).reshape(1, -1)
    y_pred_ = net.predict(x_test)
    
    y_pred = y_pred_[:,1:]
    warm = y_pred.reshape(50, 6)
    init_xs = []
    init_us = []
    init_xs.append(np.array(x0))
    state_array = warm[:,0:4]
    control_array = warm[:,4]
    
    for state in state_array:
        state = np.matrix(state).T
        init_xs.append(state)
        
    for control in control_array:
        control = np.matrix(control).T
        init_us.append(control)    
    
    
    
    
    
    cartpoleDAM = DifferentialActionModelCartpole()
    cartpoleData = cartpoleDAM.createData()
    x = cartpoleDAM.state.rand()
    u = np.zeros(1)
    cartpoleDAM.calc(cartpoleData, x, u)
    cartpoleND = crocoddyl.DifferentialActionModelNumDiff(cartpoleDAM, True) 
    timeStep = 5e-2
    cartpoleIAM = crocoddyl.IntegratedActionModelEuler(cartpoleND, timeStep)
    T  = 50
    problem = crocoddyl.ShootingProblem(np.array(x0).T, [ cartpoleIAM ]*T, cartpoleIAM)
    ddp = crocoddyl.SolverDDP(problem)
    
    
    
    cartpoleDAM2 = DifferentialActionModelCartpole()
    cartpoleData2 = cartpoleDAM2.createData()
    x2 = cartpoleDAM2.state.rand()
    u2 = np.zeros(1)
    cartpoleDAM2.calc(cartpoleData2, x2, u2)
    cartpoleND2 = crocoddyl.DifferentialActionModelNumDiff(cartpoleDAM2, True) 
    timeStep = 5e-2
    cartpoleIAM2 = crocoddyl.IntegratedActionModelEuler(cartpoleND2, timeStep)
    T  = 50
    problem2 = crocoddyl.ShootingProblem(np.array(x0).T, [ cartpoleIAM2 ]*T, cartpoleIAM2)
    ddp2 = crocoddyl.SolverDDP(problem2)
    
    start1 = timer()
    ddp.solve(init_xs, init_us, 1000)
    end1 = timer()
    
    start2 = timer()
    ddp2.solve([], [], 1000)
    end2 = timer()
    print("Warmstart time ", end1- start1, "ColdStart time ", end2 - start2)
    
    
    ddp_xs = np.array(ddp.xs)
    ddp_xs2 = np.array(ddp2.xs)
    
    iterations.append(np.array([ddp.iter, ddp2.iter]))
    time.append(np.array([end1- start1, end2 - start2]))

plotTable(iterations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-af8e200c07af> in <module>
#       6     x0 = [random.uniform(0,1), random.uniform(-3.14, 3.14), random.uniform(0., 1), 0.]
#       7     x_test = np.array(x0).reshape(1, -1)
# ----> 8     y_pred_ = net.predict(x_test)
#       9
#      10     y_pred = y_pred_[:,1:]
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1454         else:
#    1455             ins = x
# -> 1456         self._make_predict_function()
#    1457         f = self.predict_function
#    1458         return training_arrays.predict_loop(self, f, ins,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in _make_predict_function(self)
#     376                                                updates=self.state_updates,
#     377                                                name='predict_function',
# --> 378                                                **kwargs)
#     379
#     380     def _uses_dynamic_learning_phase(self):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in function(inputs, outputs, updates, **kwargs)
#    3007     return tf_keras_backend.function(inputs, outputs,
#    3008                                      updates=updates,
# -> 3009                                      **kwargs)
#    3010
#    3011
#
# ~/miniconda3/envs/env1/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in function(inputs, outputs, updates, name, **kwargs)
#    3771       raise ValueError('Session keyword arguments are not support during '
#    3772                        'eager execution. You passed: %s' % (kwargs,))
# -> 3773     return EagerExecutionFunction(inputs, outputs, updates=updates, name=name)
#    3774
#    3775   if kwargs:
#
# ~/miniconda3/envs/env1/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __init__(self, inputs, outputs, updates, name)
#    3655       global_graph = get_graph()
#    3656       if source_graph not in (exec_graph, global_graph):
# -> 3657         raise ValueError('Unknown graph. Aborting.')
#    3658
#    3659       if source_graph is global_graph and exec_graph is not global_graph:
#
# ValueError: Unknown graph. Aborting.

# %%
from plot1d import *

iterations = np.array(iterations)
time = np.array(time)
plot_1d(iterations[:,0], xlabel = "Warmstarted" ,ylabel="iterations")
plot_1d(iterations[:,1], xlabel = "oldstarted" ,ylabel="iterations")
plot_1d(time[:,0])
plot_1d(time[:,1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-cbd80474865c> in <module>
#       3 iterations = np.array(iterations)
#       4 time = np.array(time)
# ----> 5 plot_1d(iterations[:,0], xlabel = "Warmstarted" ,ylabel="iterations")
#       6 plot_1d(iterations[:,1], xlabel = "oldstarted" ,ylabel="iterations")
#       7 plot_1d(time[:,0])
#
# IndexError: too many indices for array
