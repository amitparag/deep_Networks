# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from baselineNet import kerasNet
import random
import math
import numpy as np
import pandas as pd
import crocoddyl
crocoddyl.switchToNumpyArray()

# %%
def data(nTraj:int = 1000,
         thetaVal:bool = False,
         fddp:bool = False
        ):
    model = crocoddyl.ActionModelUnicycle()
    x_data = []
    y_data = []
    
    for _ in range(nTraj):

        if thetaVal:
            initial_config = [random.uniform(-1.99, 1.99), random.uniform(-1.99, 1.99), random.uniform(0.,1.)]
        else:
            initial_config = [random.uniform(-1.99, 1.99), random.uniform(-1.99, 1.99), 0.0]
        model.costWeights = np.matrix([1, 0.3]).T
        problem = crocoddyl.ShootingProblem(np.matrix(initial_config).T, [ model ] * 30, model)
        if fddp:
            ddp = crocoddyl.SolverFDDP(problem)
        else:
            ddp = crocoddyl.SolverDDP(problem)
            
        ddp.solve([], [], 1000)
        if ddp.iter < 1000:
            xs_ = np.array(ddp.xs)
            xs = xs_[1:, :]
            us = np.array(ddp.us)
            cost = []
            for d in ddp.datas():
                cost.append(d.cost)
            cost.pop(0)    
            cost = np.array(cost).reshape(30,1)
            state = np.hstack((xs, us, cost))
            
        y_data.append(state.ravel())   
        x_data.append(initial_config)
        
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    del model, ddp
    return x_data, y_data

# %%
x_data, y_data  = data(20000)

# %%
net = kerasNet(x_data,
             y_data,
             NUNITS_INPUT = 64,
             NUNITS = 64,
             NHIDDEN = 2,
             lr = 1e-3,
             EPOCHS = 100,
             BATCHSIZE = 64,
             validation_split = 0.1,
             VERBOSE = 1,
             optimizer = "adam",
             loss = ['mean_squared_error'],
             use_gpu = True,
             saveModel = False,
             plot_results = True,
             baseline = False)
# Out:
# Using gpu!
# X_Train :  (20000, 3)  and Y_Train:  (20000, 180)
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/100
# 18000/18000 [==============================] - 1s 61us/step - loss: 0.1895 - mse: 0.1895 - rmse: 0.3681 - max_error: 5.7753 - mae: 0.1523 - val_loss: 0.0756 - val_mse: 0.0756 - val_rmse: 0.2334 - val_max_error: 4.8600 - val_mae: 0.0905
# Epoch 2/100
# 18000/18000 [==============================] - 1s 54us/step - loss: 0.0491 - mse: 0.0491 - rmse: 0.1802 - max_error: 4.4880 - mae: 0.0733 - val_loss: 0.0325 - val_mse: 0.0325 - val_rmse: 0.1384 - val_max_error: 3.9036 - val_mae: 0.0599
# Epoch 3/100
# 18000/18000 [==============================] - 1s 63us/step - loss: 0.0225 - mse: 0.0225 - rmse: 0.1071 - max_error: 3.7752 - mae: 0.0496 - val_loss: 0.0173 - val_mse: 0.0173 - val_rmse: 0.0905 - val_max_error: 3.4127 - val_mae: 0.0430
# Epoch 4/100
# 18000/18000 [==============================] - 1s 60us/step - loss: 0.0139 - mse: 0.0139 - rmse: 0.0795 - max_error: 3.3276 - mae: 0.0381 - val_loss: 0.0150 - val_mse: 0.0150 - val_rmse: 0.0754 - val_max_error: 3.3889 - val_mae: 0.0357
# Epoch 5/100
# 18000/18000 [==============================] - 1s 53us/step - loss: 0.0105 - mse: 0.0105 - rmse: 0.0677 - max_error: 2.9289 - mae: 0.0328 - val_loss: 0.0109 - val_mse: 0.0109 - val_rmse: 0.0648 - val_max_error: 2.9413 - val_mae: 0.0312
# Epoch 6/100
# 18000/18000 [==============================] - 1s 55us/step - loss: 0.0084 - mse: 0.0084 - rmse: 0.0593 - max_error: 2.6286 - mae: 0.0291 - val_loss: 0.0072 - val_mse: 0.0072 - val_rmse: 0.0543 - val_max_error: 2.4988 - val_mae: 0.0271
# Epoch 7/100
# 18000/18000 [==============================] - 1s 55us/step - loss: 0.
100
# 18000/18000 [==============================] - 1s 55us/step - loss: 0.0016 - mse: 0.0016 - rmse: 0.0200 - max_error: 1.1264 - mae: 0.0105 - val_loss: 0.0088 - val_mse: 0.0088 - val_rmse: 0.0279 - val_max_error: 2.3611 - val_mae: 0.0137
# Epoch 35/100
# 18000/18000 [==============================] - 1s 53us/step - loss: 0.0022 - mse: 0.0022 - rmse: 0.0216 - max_error: 1.2432 - mae: 0.0111 - val_loss: 0.0025 - val_mse: 0.0025 - val_rmse: 0.0234 - val_max_error: 1.4009 - val_mae: 0.0120
# Epoch 36/100
# 18000/18000 [==============================] - 1s 54us/step - loss: 0.0015 - mse: 0.0015 - rmse: 0.0195 - max_error: 1.0697 - mae: 0.0102 - val_loss: 0.0044 - val_mse: 0.0044 - val_rmse: 0.0261 - val_max_error: 1.7462 - val_mae: 0.0133
# Epoch 37/100
# 18000/18000 [==============================] - 1s 50us/step - loss: 0.0025 - mse: 0.0025 - rmse: 0.0220 - max_error: 1.2972 - mae: 0.0113 - val_loss: 0.0041 - val_mse: 0.0041 - val_rmse: 0.0218 - val_max_error: 1.6016 - val_mae: 0.0113
# Epoch 38/100
# 18000/18000 [==============================] - 1s 53us/step - loss: 0.0024 - mse: 0.0024 - rmse: 0.0217 - max_error: 1.2505 - mae: 0.0112 - val_loss: 0.0055 - val_mse: 0.0055 - val_rmse: 0.0208 - val_max_error: 1.7930 - val_mae: 0.0106
# Epoch 39/100
# 18000/18000 [==============================] - 1s 51us/step - loss: 0.0021 - mse: 0.0021 - rmse: 0.0199 - max_error: 1.0772 - mae: 0.0103 - val_loss: 0.0023 - val_mse: 0.0023 - val_rmse: 0.0250 - val_max_error: 1.2701 - val_mae: 0.0124
# Epoch 40/100
# 18000/18000 [==============================] - 1s 52us/step - loss: 0.0018 - mse: 0.0018 - rmse: 0.0190 - max_error: 1.1116 - mae: 0.0099 - val_loss: 0.0044 - val_mse: 0.0044 - val_rmse: 0.0230 - val_max_error: 1.5900 - val_mae: 0.0119
# Epoch 41/100
# 18000/18000 [==============================] - 1s 61us/step - loss: 0.0019 - mse: 0.0019 - rmse: 0.0199 - max_error: 1.1016 - mae: 0.0103 - val_loss: 0.0019 - val_mse: 0.0019 - val_rmse: 0.0184 - val_max_error: 1.2703 - val_mae: 0.0094
# Epoch 42/100
# 18000/18000 [==============================] - 1s 55us/step - loss: 0.0016 - mse: 0.0016 - rmse: 0.0184 - max_error: 1.0768 - mae: 0.0096 - val_loss: 0.0030 - val_mse: 0.0030 - val_rmse: 0.0199 - val_max_error: 1.3877 - val_mae: 0.0112
# Epoch 43/100
# 18000/18000 [==============================] - 1s 52us/step - loss: 0.0013 - mse: 0.0013 - rmse: 0.0169 - max_error: 0.9632 - mae: 0.0090 - val_loss: 0.0021 - val_mse: 0.0021 - val_rmse: 0.0204 - val_max_error: 1.1137 - val_mae: 0.0115
# Epoch 44/100
# 18000/18000 [==============================] - 1s 52us/step - loss: 0.0022 - mse: 0.0022 - rmse: 0.0201 - max_error: 1.1935 - mae: 0.0104 - val_loss: 0.0040 - val_mse: 0.0040 - val_rmse: 0.0223 - val_max_error: 1.3933 - val_mae: 0.0113
# Epoch 45/100
# 18000/18000 [==============================] - 1s 51us/step - loss: 0.0017 - mse: 0.0017 - rmse: 0.0190 - max_error: 1.0491 - mae: 0.0099 - val_loss: 0.0039 - val_mse: 0.0039 - val_rmse: 0.0185 - val_max_error: 1.5784 - val_mae: 0.0096
# Epoch 46/100
# 18000/18000 [==============================] - 1s 57us/step - loss: 0.0017 - mse: 0.0017 - rmse: 0.0176 - max_error: 1.0571 - mae: 0.0091 - val_loss: 0.0025 - val_mse: 0.0025 - val_rmse: 0.0214 - val_max_error: 1.3137 - val_mae: 0.0108
# Epoch 47/100
# 18000/18000 [==============================] - 1s 59us/step - loss: 0.0016 - mse: 0.0016 - rmse: 0.0181 - max_error: 1.0384 - mae: 0.0094 - val_loss: 0.0013 - val_mse: 0.0013 - val_rmse: 0.0157 - val_max_error: 0.9512 - val_mae: 0.0083
# Epoch 48/100
# 18000/18000 [==============================] - 1s 57us/step - loss: 0.0018 - mse: 0.0018 - rmse: 0.0175 - max_error: 1.0364 - mae: 0.0091 - val_loss: 0.0015 - val_mse: 0.0015 - val_rmse: 0.0165 - val_max_error: 1.0000 - val_mae: 0.0094
# Epoch 49/100
# 18000/18000 [==============================] - 1s 58us/step - loss: 0.0016 - mse: 0.0016 - rmse: 0.0174 - max_error: 1.0353 - mae: 0.0091 - val_loss: 0.0012 - val_mse: 0.0012 - val_rmse: 0.0191 - val_max_error: 0.9520 - val_mae: 0.0097
# Epoch 50/100
# 18000/18000 [==============================] - 1s 54us/step - loss: 0.0021 - mse: 0.0021 - rmse: 0.0194 - max_error: 1.1159 - mae: 0.0100 - val_loss: 0.0040 - val_mse: 0.0040 - val_rmse: 0.0162 - val_max_error: 1.3590 - val_mae: 0.0082
# Epoch 51/100
# 18000/18000 [==============================] - 1s 56us/step - loss: 0.0017 - mse: 0.0017 - rmse: 0.0172 - max_error: 0.9957 - mae: 0.0089 - val_loss: 0.0013 - val_mse: 0.0013 - val_rmse: 0.0198 - val_max_error: 1.0316 - val_mae: 0.0105
# Epoch 52/100
# 18000/18000 [==============================] - 1s 55us/step - loss: 0.0013 - mse: 0.0013 - rmse: 0.0167 - max_error: 0.9015 - mae: 0.0087 - val_loss: 0.0011 - val_mse: 0.0011 - val_rmse: 0.0182 - val_max_error: 0.9742 - val_mae: 0.0093
# Epoch 53/100
# 18000/18000 [==============================] - 1s 52us/step - loss: 0.0014 - mse: 0.0014 - rmse: 0.0176 - max_error: 0.9756 - mae: 0.0092 - val_loss: 0.0027 - val_mse: 0.0027 - val_rmse: 0.0168 - val_max_error: 1.3218 - val_mae: 0.0089
# Epoch 54/100
# 18000/18000 [==============================] - 1s 53us/step - loss: 0.0019 - mse: 0.0019 - rmse: 0.0184 - max_error: 1.0199 - mae: 0.0095 - val_loss: 0.0090 - val_mse: 0.0090 - val_rmse: 0.0299 - val_max_error: 2.5459 - val_mae: 0.0145
# Epoch 55/100
# 18000/18000 [==============================] - 1s 53us/step - loss: 0.0014 - mse: 0.0014 - rmse: 0.0164 - max_error: 0.9385 - mae: 0.0086 - val_loss: 0.0032 - val_mse: 0.0032 - val_rmse: 0.0228 - val_max_error: 1.5204 - val_mae: 0.0115
# Epoch 56/100
#  2304/18000 [==>...........................] - ETA: 0s - loss: 8.8966e-04 - mse: 8.8965e-04 - rmse: 0.0171 - max_error: 0.7540 - mae: 0.0090

# %%
## Predictions
warmstart = []
for _ in range(1000):
    # Single row -> reshape(1, -1)............single feature -> reshape(-1, 1)
    initial_config = np.array([random.uniform(-1.99, 1.99), random.uniform(-1.99, 1.99), 0.]).reshape(1, -1)
    y_prediction = net.predict(initial_config)
    
    result = np.hstack((initial_config, y_prediction))
    warmstart.append(result)
warmstart = np.squeeze(np.array(warmstart))

# %%
np.savetxt("warmstart.csv", warmstart, delimiter=",")
